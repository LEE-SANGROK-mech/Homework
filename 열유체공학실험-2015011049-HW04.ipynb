# %% [markdown]
# <a href="https://colab.research.google.com/github/LEE-SANGROK-mech/Homework/blob/master/%EC%97%B4%EC%9C%A0%EC%B2%B4%EA%B3%B5%ED%95%99%EC%8B%A4%ED%97%98-2015011049-HW04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !find / -iname 'libdevice'
# !find / -iname 'libnvvm.so'

import os
os.environ['NUMBAPRO_LIBDEVICE'] = "/usr/local/cuda-10.1/nvvm/libdevice"
os.environ['NUMBAPRO_NVVM'] = "/usr/local/cuda-10.1/nvvm/lib64/libnvvm.so"

import numpy as np
from numba import jit, vectorize, cuda

gugudan_name=["normal gugudan", "numpy gugudan", "numba gugudan", "cuda gugudan"]
gugudan=[]
time=[]

numpy_list=np.arange(1,10)
def normal_gugudan(x):
  return list(range(x, x*10, x))
def numpy_gugudan(x):
  return np.multiply(x, numpy_list)
@jit(nopython=True)
def numba_gugudan(x):
  return np.multiply(x, numpy_list)
@vectorize(['int64(int64, int64)'], target='cuda')
def cuda_gugudan(x,y):
  return x*y

integer=int(input("input an integer:"))

gugudan.append(normal_gugudan(integer))
gugudan.append(numpy_gugudan(integer))
gugudan.append(numba_gugudan(integer))
gugudan.append(cuda_gugudan(integer, numpy_list))

for i in range(len(gugudan_name)):
  print(gugudan_name[i])
  for j in range(numpy_list.shape[0]):
    print(gugudan[i][j])
    print()
print("normal gugudan compiling time(s):", end="")
# %timeit normal_gugudan
print("numpy gugudan compiling time(s):", end="")
# %timeit numpy_gugudan
print("numba gugudan compiling time(s)", end="")
# %timeit numba_gugudan
print("cuda gugudan compiling time(s):", end="")
# %timeit cuda_gugudan
# Out:
# /usr/local/cuda-10.1/nvvm/libdevice
# /usr/local/cuda-10.0/nvvm/libdevice
# /usr/local/cuda-10.1/nvvm/lib64/libnvvm.so
# /usr/local/cuda-10.0/nvvm/lib64/libnvvm.so
# input an integer:3
# normal gugudan
# 3
#
# 6
#
# 9
#
# 12
#
# 15
#
# 18
#
# 21
#
# 24
#
# 27
#
# numpy gugudan
# 3
#
# 6
#
# 9
#
# 12
#
# 15
#
# 18
#
# 21
#
# 24
#
# 27
#
# numba gugudan
# 3
#
# 6
#
# 9
#
# 12
#
# 15
#
# 18
#
# 21
#
# 24
#
# 27
#
# cuda gugudan
# 3
#
# 6
#
# 9
#
# 12
#
# 15
#
# 18
#
# 21
#
# 24
#
# 27
#
# normal gugudan compiling time(s):10000000 loops, best of 3: 20.5 ns per loop
# numpy gugudan compiling time(s):10000000 loops, best of 3: 21.9 ns per loop
# numba gugudan compiling time(s)10000000 loops, best of 3: 18.4 ns per loop
# cuda gugudan compiling time(s):10000000 loops, best of 3: 26.1 ns per loop
